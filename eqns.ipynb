# %% [markdown]
# $$\tau \frac{d\mathbf{x}}{dt} = -\tau + J\phi(\mathbf{x})$$
#
# $$\mathbf{r}(t) = \phi(\mathbf{x}(t))$$

# %% [markdown]
# $$\tau \frac{d\mathbf{x}}{dt} = -\mathbf{x} + J_0\phi(\mathbf{x}) + B\mathbf{u}(t) + MN^T\phi(\mathbf{x})$$

# %% [markdown]
# $$\tau \frac{d\mathbf{x}}{dt} = -\mathbf{x} + J_0\phi(\mathbf{x}) + CW^T\boldsymbol{\psi}(\mathbf{x})$$
#
# $$\tau \frac{d\mathbf{x}}{dt} = -\mathbf{x} + J_0\phi(\mathbf{x}) + \sum_l \mathbf{c}_l \Delta \mathbf{w}_l^T \boldsymbol{\psi}(\mathbf{x})$$

# %% [markdown]
# $$\mathbf{x} \in \mathbb{R}^D$$
#
# $$M \in \mathbb{R}^{D \times L}$$
#
# $$N^T \in \mathbb{R}^{L \times D}$$
#
# $$\phi(\mathbf{x}) \in \mathbb{R}^D$$
#
# $$MN^T \in \mathbb{R}^{D \times D}$$
#
# $$C \in \mathbb{R}^{D \times L}$$
#
# $$W^T \in \mathbb{R}^{L \times N}$$
#
# $$\boldsymbol{\psi}(\mathbf{x}) \in \mathbb{R}^N$$

# %% [markdown]
# $$J_0 = 0$$
#
# $$W(0) = 0$$
#
# $$B = 0$$
#
# $$\tau \frac{d\mathbf{x}}{dt} = -\mathbf{x}$$

# %% [markdown]
# $$\boldsymbol{\psi}(\mathbf{x}) = \text{Sigmoid}(J^\psi \mathbf{x}) \in \mathbb{R}_+^{N}$$
#
# $$J^\psi \in \mathbb{R}^{N \times 2}$$

# %% [markdown]
# $$k(\mathbf{x}^*, \mathbf{x}) = \boldsymbol{\psi}(\mathbf{x}^*)^T \boldsymbol{\psi}(\mathbf{x})$$

# %% [markdown]
# $$D_l(t) = \sum_{t^* \in T_l} \delta(t-t^*)$$

# %% [markdown]
# $$\boldsymbol{\psi}(\mathbf{x}) = J^\psi \mathbf{x}$$

# %% [markdown]
# $$\boldsymbol{\psi}(\mathbf{x}) = (1 + \text{tanh}(\mathbf{x}))/2$$
#
# $$\boldsymbol{\psi}(\mathbf{x}) = (1 + \text{tanh}(J^\psi\mathbf{x}))/2$$
#
# $$\boldsymbol{\psi}(\mathbf{x}) = (1 + \text{tanh}(\mathbf{x}))/2$$
#
# $$\boldsymbol{\psi}(\mathbf{x}) = \text{K-WTA}[(1 + \text{tanh}(J^\psi\mathbf{x}))/2]$$

# %% [markdown]
# $$
# C =
# \begin{bmatrix}
# \begin{bmatrix} 0 \\ -1 \end{bmatrix}
# \begin{bmatrix} 0 \\ 1 \end{bmatrix}
# \end{bmatrix}.
# $$

# %% [markdown]
# $$\boldsymbol{\psi}(\mathbf{x}) = (1 + \tanh(J^\psi \mathbf{x}))/\sqrt{2N})$$

# %% [markdown]
# $\boldsymbol{\psi}(\mathbf{x}) = \text{K-WTA}(\text{tanh}(J^\psi\mathbf{x})))/\sqrt{K}$

# %% [markdown]
# $$k(\mathbf{x}, \mathbf{x}^*)$$

# %% [markdown]
# $$\to$$

# %% [markdown]
# $$1 - \theta(\mathbf{x}, \mathbf{x}^*)/\pi$$

# %% [markdown]
# $$N, \text{gain} \to \infty$$

# %% [markdown]
# $$\sim\mathcal{N}(0, \text{gain})$$

# %% [markdown]
# $$\prod_{t'=t}^T \mathcal{D}_{\mathbf{x}^{t'}\mathbf{x}^{t'-1}} = \prod_{t'=t}^T \frac{d\mathbf{x}^{t'}}{d\mathbf{x}^{t'-1}}$$

# %% [markdown]
# $$E \equiv \text{Loss} = \sum_t ||\mathbf{x}(t) - \mathbf{x}(t)||^2$$

# %% [markdown]
# $$\frac{dE}{dt} = $$

# %% [markdown]
# $$
# = \mathcal{D}_{L\mathbf{x}} \mathcal{D}_{\mathbf{x}W}
# + \mathcal{D}_{L\mathbf{y}} \mathcal{D}_{\mathbf{y}\mathbf{x}} \mathcal{D}_{\mathbf{x}W}
# + \mathcal{D}_{L\mathbf{z}} \mathcal{D}_{\mathbf{z}\mathbf{y}} \mathcal{D}_{\mathbf{y}\mathbf{x}} \mathcal{D}_{\mathbf{x}W}
# $$
#
# $$
# + \mathcal{D}_{L \mathbf{y}} \mathcal{D}_{\mathbf{y}W}
# + \mathcal{D}_{L \mathbf{z}} \mathcal{D}_{\mathbf{z}\mathbf{y}} \mathcal{D}_{\mathbf{y}W}
# + \mathcal{D}_{L\mathbf{z}} \mathcal{D}_{\mathbf{z}W}
# $$

# %% [markdown]
# $$\tau \hat{\mathbf{v}}(\mathbf{x}) = -\mathbf{x} + \mathbf{f}_{base} + $$

# %% [markdown]
# $$\tau \hat{\mathbf{v}}(\mathbf{x}) + \mathbf{x} - \mathbf{f}_{base} = $$

# %% [markdown]
# $$\tau \frac{d\mathbf{x}}{dt} =  - \mathbf{x} + \mathbf{f}_{base} + $$
